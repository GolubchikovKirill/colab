# %% [markdown]
# <a href="https://colab.research.google.com/github/GolubchikovKirill/colab/blob/main/py_cycles.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Циклы
#
# Автор: **Булыгин Олег**
# * [Я в LinkedIn](https://www.linkedin.com/in/obulygin/)
# * [Мой канал в ТГ по Python](https://t.me/pythontalk_ru)
# * [Чат канала](https://t.me/pythontalk_chat)
# * [Блог в Телетайпе](https://teletype.in/@pythontalk)
#
# Ссылочки в ноутбуке ведут на полезные доп. материалы, обязательно всё изучайте :)

# %% [markdown]
# **Цикл** — конструкция языка, при помощи которой можно повторять код, написанный в теле цикла.
#
# **Тело цикла** — это набор команд, находящихся на одном и более уровне отступов от отступа самого цикла (то есть команды, находящиеся внутри него).
#
# **Итерация** — это один шаг цикла, повторное выполнение кода, прописанного в теле цикла.
#
# Например, говоря «на пятой итерации цикла», мы будем иметь в виду, что рассматривается пятый шаг цикла и тело цикла выполняется в пятый раз.
#
# В Python существует два вида цикла:
#
# * цикл `while` (англ. «пока») позволяет выполнить одну и ту же последовательность действий, пока выполняется какое-либо условие.
# * цикл `for` (англ. «для») позволяет "перебрать" элементы составного объекта, каждый раз выполняя указанные действия.

# %% [markdown]
# ## Цикл `while`
#
# Выполняется до тех пор, пока истинно указанное условие. Как только оно становится ложным, цикл прерывается.
# ```python
# while условие:
#     # Начало блока кода с телом цикла
#     # Пока условие истинно, цикл выполняется
#     ...
#     ...
#     ...
#     # Конец блока кода с телом цикла
# # Код, который будет выполняться после цикла
# ```

# %% [markdown]
# Предположим, что мы положили 100000 у.е. в банк под 5% годовых (то есть в конце каждого года на счету будет на 5% больше денег, чем в его начале). Через сколько лет деньги удвоятся?

# %%
money = 100000
year = 0
yearly_multiplier = 1.05
money_target = money * 2

while money < money_target:
    money *= yearly_multiplier
    # money = money * yearly_multiplier
    year += 1
    print(f'Год {year}: денег будет {money:.2f}')

print(f'Деньги удвоятся через {year} лет.')
# Out:
# Год 1: денег будет 105000.00
# Год 2: денег будет 110250.00
# Год 3: денег будет 115762.50
# Год 4: денег будет 121550.62
# Год 5: денег будет 127628.16
# Год 6: денег будет 134009.56
# Год 7: денег будет 140710.04
# Год 8: денег будет 147745.54
# Год 9: денег будет 155132.82
# Год 10: денег будет 162889.46
# Год 11: денег будет 171033.94
# Год 12: денег будет 179585.63
# Год 13: денег будет 188564.91
# Год 14: денег будет 197993.16
# Год 15: денег будет 207892.82
# Деньги удвоятся через 15 лет.

# %% [markdown]
# Для успешного выполнения цикла условие должно быть построено таким образом, чтобы оно когда-нибудь стало ложным, то есть переменные, участвующие в условии, должны изменяться в теле цикла. Иначе мы уйдём в бесконечный цикл (infinite loop).

# %%
money = 100000
year = 0
yearly_multiplier = 1.05
money_target = money * 2

while money < money_target:
    money /= yearly_multiplier  # тут перепутали действие
    year += 1
    print(f'Год {year}: денег будет {money :.2f}')

print(f'Деньги удвоятся через {year} лет.')
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
#
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/iostream.py in write(self, string)
#     400             is_child = (not self._is_master_process())
#     401             # only touch the buffer in the IO thread to avoid races
# --> 402             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     403             if is_child:
#     404                 # mp.Pool cannot be trusted to flush promptly (or ever),
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/iostream.py in schedule(self, f)
#     201             self._events.append(f)
#     202             # wake event thread (message content is ignored)
# --> 203             self._event_pipe.send(b'')
#     204         else:
#     205             f()
#
# /usr/local/lib/python3.10/dist-packages/zmq/sugar/socket.py in send(self, data, flags, copy, track, routing_id, group)
#     618                 )
#     619             data.group = group
# --> 620         return super().send(data, flags=flags, copy=copy, track=track)
#     621
#     622     def send_multipart(
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# /usr/local/lib/python3.10/dist-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %% [markdown]
# Напишем программу, которая последовательно запрашивает у пользователя числа (по одному за раз) и после первого нуля выводит сумму всех ранее введенных чисел.

# %%
sum_ = 0
number = 1

while number:
    number = int(input('Введите число'))
    sum += number

print(f'Сумма: {sum_}')
# Out:
# Введите число21
# Введите число234
# Введите число345
# Введите число567
# Введите число0
# Сумма: 1167

# %%
number = 0

if number:
    print('Число не ноль')

# %% [markdown]
# [Гипотеза Коллатца](https://ru.wikipedia.org/wiki/Гипотеза_Коллатца) гласит, что любое натуральное число сводится к единице при следующих действиях над ним:
#
# а) если число четное, то разделить его пополам,
#
# б) если число нечетное, то умножить его на 3, прибавить 1 и результат разделить на 2.
#
# Над вновь полученным числом вновь повторить действия `a` или `б` в зависимости от чётности числа. Рано или поздно число станет равным 1.
#
# Кому интересно, можно ещё посмотреть ролик на [YouTube](
# https://www.youtube.com/watch?v=QgzBDZwanWA).
#
# Напишем программу, проверяющую гипотезу Коллатца. Пусть пользователь вводит любое натуральное число. Будем выполнять в цикле над ним вышеуказанные действия, пока оно не станет равным 1. Если гипотеза верна, то рано или поздно цикл закончится, а если нет - то произойдет зацикливание программы.

# %%
number = int(input('Введите число'))
counter = 0
while number != 1:
    if number % 2 == 0:
        number //= 2
    else:
        number = (number * 3 + 1) // 2
    counter += 1

print(f'Получили {number} после {counter} итераций')
# Out:
# Введите число15986516715689156951675161598315368935615369815396813568354961834193568135648913568913569143689346834968134196313461346913569153791356975696819536918569815691346951365756891571655156351637
# Получили 1 после 2849 итераций

# %% [markdown]
# ## Цикл `for`
#
# Цикл `for` организуется следующим образом:
# ```
# for value in iterator:
#     # Начало блока кода с телом цикла
#     ...
#     ...
#     ...
#     # Конец блока кода с телом цикла
# # Код, который будет выполняться после цикла
# ```
#
# `value` — переменная цикла (может иметь другое название), в которой на каждой итерации содержится текущее значение из итерируемого объекта `iterator`.
#
# `iterator` — итерируемый объект, из которого на каждой итерации достаются элементы (например, список, словарь, кортеж, строка и т. д.).

# %% [markdown]
# ### Итерация по строкам

# %%
company_name = 'Netology'

# мы сами задаем имя переменной в которую будут последовательно помещаться каждый элемент нашего объекта
for letter in company_name:
    # print(letter)
    print(f'*{letter}*', end='')
# Out:
# *N**e**t**o**l**o**g**y*

# %% [markdown]
# ### Итерация по спискам

# %% [markdown]
# В нашем распоряжении есть список масс товаров, предназначенных для перевозки (в килограммах).
#
# Товары, которые весят больше 100 килограммов, необходимо перевозить на грузовой машине, а товары меньшей массы можно перевезти на легковой.
#
# Напишем алгоритм, который распределял бы товары по типам машин.

# %%
weight_of_products = [10, 42.4, 240.1, 101.5, 98, 0.4, 0.3, 15]
# weight_of_products = sorted(weight_of_products)
max_weight = 100

# Создаём цикл по элементам списка со значениями массы товаров
for weight in weight_of_products:
    if weight < max_weight:
        print(f'Товар весит {weight} кг. и отправляется на перевозку легковой машиной.')
    else:
        print(f'Товар весит {weight} кг. и отправляется на перевозку грузовой машиной.')
# Out:
# Товар весит 0.3 кг. и отправляется на перевозку легковой машиной.
# Товар весит 0.4 кг. и отправляется на перевозку легковой машиной.
# Товар весит 10 кг. и отправляется на перевозку легковой машиной.
# Товар весит 15 кг. и отправляется на перевозку легковой машиной.
# Товар весит 42.4 кг. и отправляется на перевозку легковой машиной.
# Товар весит 98 кг. и отправляется на перевозку легковой машиной.
# Товар весит 101.5 кг. и отправляется на перевозку грузовой машиной.
# Товар весит 240.1 кг. и отправляется на перевозку грузовой машиной.

# %% [markdown]
# Выведём на экран список всех слов длиннее `n` букв из текста

# %%
text = 'Python — высокоуровневый язык программирования, ориентированный на повышение производительности разработчика и читаемости кода.'
n = 10

# %%
text.split()
# Out:
# ['Python',
#  '—',
#  'высокоуровневый',
#  'язык',
#  'программирования,',
#  'ориентированный',
#  'на',
#  'повышение',
#  'производительности',
#  'разработчика',
#  'и',
#  'читаемости',
#  'кода.']

# %%
res = []

for word in text.split():
    word = word.strip(',.!;:— ')
    print(word)
    if len(word) > n:
        res.append(word)


print(res)
# Out:
# Python
#
# высокоуровневый
# язык
# программирования
# ориентированный
# на
# повышение
# производительности
# разработчика
# и
# читаемости
# кода
# ['высокоуровневый', 'программирования', 'ориентированный', 'производительности', 'разработчика']

# %% [markdown]
# ### Итерация по вложенным спискам

# %%
companies_capitalization = [
    ['Апельсин', 1.3],
    ['Максисофт', 1.5],
    ['Головакнига', 0.8],
    ['Никола', 2.2]
]

for company in companies_capitalization:
    # print(company)
    print(f'Компания "{company[0]}" имеет капитализацию {company[1]} триллионов кредитов.')
# Out:
# Компания "Апельсин" имеет капитализацию 1.3 триллионов кредитов.
# Компания "Максисофт" имеет капитализацию 1.5 триллионов кредитов.
# Компания "Головакнига" имеет капитализацию 0.8 триллионов кредитов.
# Компания "Никола" имеет капитализацию 2.2 триллионов кредитов.

# %% [markdown]
# Можем использовать распаковку:

# %%
companies_capitalization = [
    ['Апельсин', 1.3],
    ['Максисофт', 1.5],
    ['Головакнига', 0.8],
    ['Никола', 2.2]
]

for company_name, cap in companies_capitalization:
    print(f'Компания "{company_name}" имеет капитализацию {cap} триллионов кредитов.')
# Out:
# Компания "Апельсин" имеет капитализацию 1.3 триллионов кредитов.
# Компания "Максисофт" имеет капитализацию 1.5 триллионов кредитов.
# Компания "Головакнига" имеет капитализацию 0.8 триллионов кредитов.
# Компания "Никола" имеет капитализацию 2.2 триллионов кредитов.

# %% [markdown]
# Посчитаем сумму элементов по главной диагонали квадратной матрицы

# %%
data = [
    [13, 25, 23, 34],
    [45, 32, 44, 47],
    [12, 33, 23, 95],
    [13, 53, 34, 35]
]

# %%
sum_ = 0
index = 0
for row in data:
    # print(row)
    sum_ += row[index]
    index += 1

print(sum_)
# Out:
# 103

# %%
sum_ = 0
index = -1
for row in data:
    # print(row)
    sum_ += row[index]
    index -= 1

print(sum_)
# Out:
# 124

# %% [markdown]
# ## Вложенные циклы
#
# Первый цикл называют циклом по первому уровню вложенности, второй цикл — циклом по второму уровню вложенности.  Если уровней вложенности всего два, то удобнее называть первый цикл *внешним*, а второй — внутренним (*вложенным*).
#
# Внутренний цикл так же отделяется отступом (как и любые более вложенные).

# %% [markdown]
# Напишем программу, которая выведет на экран таблицу умножения (Таблица Пифагора). Для этой задачи нам пригодится функция `range`.
#
# Функция `range` генерирует числовую последовательность в заданном диапазоне и с указанным шагом.
#
# Если передаём один аргумент, то генерация будет идти от нуля до указанного числа невключительно:

# %%
res = range(5)

for i in res:
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# Если передать 2 аргумента, то генерация будет идти от заданного числа до указанного невключительно:

# %%
res = range(2, 5)

for i in res:
    print(i)
# Out:
# 2
# 3
# 4

# %% [markdown]
# Также можем указать шаг:

# %%
res = range(2, 10, 2)

for i in res:
    print(i)
# Out:
# 2
# 4
# 6
# 8

# %% [markdown]
# Теперь выведем таблицу Пифагора:

# %%
for row in range(1, 10):
    for col in range(1, 10):
        print(row*col, end='\t')
    print()
# Out:
# 1	2	3	4	5	6	7	8	9
# 2	4	6	8	10	12	14	16	18
# 3	6	9	12	15	18	21	24	27
# 4	8	12	16	20	24	28	32	36
# 5	10	15	20	25	30	35	40	45
# 6	12	18	24	30	36	42	48	54
# 7	14	21	28	35	42	49	56	63
# 8	16	24	32	40	48	56	64	72
# 9	18	27	36	45	54	63	72	81

# %%
print(1, end=',')
print(2)
# Out:
# 1,2

# %%
help(print)
# Out:
# Help on built-in function print in module builtins:
#
# print(...)
#     print(value, ..., sep=' ', end='\n', file=sys.stdout, flush=False)
#
#     Prints the values to a stream, or to sys.stdout by default.
#     Optional keyword arguments:
#     file:  a file-like object (stream); defaults to the current sys.stdout.
#     sep:   string inserted between values, default a space.
#     end:   string appended after the last value, default a newline.
#     flush: whether to forcibly flush the stream.

# %% [markdown]
# Выведем фамилии построчно с указанием профессии в формате:
#
# ```
# IT:
# Гейтс
# Джобс
# Возняк
#
# Искусство:
# Пикассо
# Моне
# Ван Гог
#
# ...
# ```

# %%
professions = ['IT', 'Искусство', 'Спорт', 'Музыка']
persons = [['Гейтс', 'Джобс', 'Возняк'], ['Пикассо', 'Моне', 'Ван Гог'], ['Федерер', 'Надаль'], ['Моцарт', 'Бах']]

# %%
for pro, names in zip(professions, persons):
    # print(pro, names)
    print(f'{pro}:')
    for name in names:
        print(name)
    print()
# Out:
# IT:
# Гейтс
# Джобс
# Возняк
#
# Искусство:
# Пикассо
# Моне
# Ван Гог
#
# Спорт:
# Федерер
# Надаль
#
# Музыка:
# Моцарт
# Бах

# %%
list_1 = [1, 2, 3]
list_2 = ('a', 'b', 'c')

list(zip(list_1, list_2))
# Out:
# [(1, 'a'), (2, 'b'), (3, 'c')]

# %%
for pro, names in zip(professions, persons):
    print(f'{pro}:')
    print('\n'.join(names))
    print()
# Out:
# IT:
# Гейтс
# Джобс
# Возняк
#
# Искусство:
# Пикассо
# Моне
# Ван Гог
#
# Спорт:
# Федерер
# Надаль
#
# Музыка:
# Моцарт
# Бах

# %% [markdown]
# ## break и continue

# %% [markdown]
# Бывают ситуации, когда необходимо в какой-то момент остановить выполнение цикла.
#
# Тут пригодится `break`. Он может использоваться как в цикле `while`, так и в цикле `for`.

# %%
phrase = '640Кб должно хватить для любых задач. Билл Гейтс (по легенде)'

for letter in phrase:
    if letter == ' ':
        break
    print(letter, end='')
# Out:
# 640Кб

# %% [markdown]
# Делаем инвентарь для персонажа, который может уместить только 3 предмета. Пусть изначально инвентарь пуст. Будем его наполнять до тех пор, пока места не закончится.

# %%
to_inventory = ['Мокасины скорости', 'Маска-лицехват', 'Шапочка из фольги', 'Философский камень']

inventory = []

for item in to_inventory:
    if len(inventory) == 3:
        print('Места больше нет!')
        # Завершаем работу цикла
        break
    inventory.append(item)

print(inventory)
# Out:
# Места больше нет!
# ['Мокасины скорости', 'Маска-лицехват', 'Шапочка из фольги']

# %% [markdown]
# Возможна ситуация, когда в процессе выполнения цикла обнаружилось условие, при выполнении которого дальнейшие действия в цикле не должны выполняться и нужно перейти на следующую итерацию.
#
# Если в теле цикла встречается ключевое слово `continue`, то цикл пропускает весь код до конца тела цикла и переходит на следующий шаг.

# %%
phrase = '640Кб должно хватить для любых задач. Билл Гейтс (по легенде)'

for letter in phrase:
    if letter == ' ':
        continue
    print(letter, end='')
# Out:
# 640Кбдолжнохватитьдлялюбыхзадач.БиллГейтс(полегенде)

# %% [markdown]
# У нас есть список с разными объектами. Нам нужно просуммировать только чётные числа.

# %%
some_els = [10, 5, 8, 2, "abc", 12, 3]

result = 0

for el in some_els:
    if type(el) != int:
        print(f"Элемент {el} не является числом:")
        continue
    if el % 2 == 0:
        result += el
print(f"Сумма четных чисел: {result}")
# Out:
# Элемент abc не является числом:
# Сумма четных чисел: 32

# %% [markdown]
# ## `else` и циклы
#
# `else` выполняется после завершения цикла, если цикл не был прерван инструкцией `break`. Если же в цикле отрабатывает `break`, то `else` не исполнится.

# %% [markdown]
# Напишем игру "Угадай число"

# %%
import random

number = random.randint(1, 100)
print(number)

max_tries = 3
tries = 0

while tries < max_tries:
    guess = int(input('Назови свой вариант'))
    if guess < number:
        print('Загаданное число больше')
    elif guess > number:
        print('Загаданное число меньше')
    else:
        print('Ты победил!')
        break
    tries += 1
else:
    print('Ты проиграл')
    print(f'Было загадано число: {number}')
# Out:
# 59
# Назови свой вариант50
# Загаданное число больше
# Назови свой вариант75
# Загаданное число меньше
# Назови свой вариант59
# Ты победил!

# %% [markdown]
# Напишем программу для проверки логина и пароля
#
# 1) логин и пароль пользователя хранится в переменной
#
# 2) будем давать пользователю `k` попыток на ввод логина и пароля
#
# 3) если после трех попыток вверного ввода не было, то заблокируем вход - вывести на экран сообщение "Вход заблокирован"
#
# 4) если пароль и логин были введены верно, то вывести на экран сообщение "Добро пожаловать!"

# %%
login_correct = 'admin'
pswd_correct = 'admin'
k = 3

for attempt in range(k, 0, -1):
    login = input('Введите логин')
    pswd = input('Введите пароль')
    if login != login_correct or pswd != pswd_correct:
        print(f'Осталось попыток: {attempt-1}')
    else:
        print('Добро пожаловать!')
        break
else:
    print('Вход заблокирован')


print(23465)
print(437457)
# Out:
# Введите логинa;orihy
# Введите парольdsghk
# Осталось попыток: 2
# Введите логинsgkj
# Введите парольsgkj
# Осталось попыток: 1
# Введите логинgj
# Введите парольsgjh
# Осталось попыток: 0
# Вход заблокирован
